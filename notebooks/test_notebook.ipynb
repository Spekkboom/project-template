# %% [markdown]
# ___
# # Test Notebook
# ___

# %% [markdown]
# ## Setup

# %% [markdown]
# Editable Install

# %%
# %pip install -e ../. -qq
# %load_ext autoreload
# %autoreload 2
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Imports

# %%
import module

# %% [markdown]
# ## Notebook

# %% [markdown]
# ___
